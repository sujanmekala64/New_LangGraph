# %%
from langchain_ollama import ChatOllama
from dotenv import load_dotenv 
load_dotenv() 
from typing import TypedDict, Literal
from langgraph.graph import StateGraph, START, END

# %%
import os 
llm = ChatOllama(
    model="gpt-oss:20b-cloud",
    base_url = os.getenv("OLLAMA_BASE_URL"),
    headers = {"Authorization":f"Bearer {os.getenv("OLLAMA_API_KEY")}"}
)

# %%
from pydantic import BaseModel, Field

# %%
class SentimentSchema(BaseModel):
    sentiment: Literal["Positive","Negative"]

# %%
structured_llm = llm.with_structured_output(SentimentSchema, method="json_schema")

# %%
prompt = """Classify the sentiment of the following review.

Return ONLY one word: Positive or Negative.

Review: The Structure is too good """
structured_llm.invoke(prompt).sentiment
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /workspaces/New_LangGraph/myenv/lib/python3.12/site-packages/langchain_core/output_parsers/json.py:88, in JsonOutputParser.parse_result(self, result, partial)
#      87 try:
# ---> 88     return parse_json_markdown(text)
#      89 except JSONDecodeError as e:
#
# File /workspaces/New_LangGraph/myenv/lib/python3.12/site-packages/langchain_core/utils/json.py:163, in parse_json_markdown(json_string, parser)
#     162     json_str = json_string if match is None else match.group(2)
# --> 163 return _parse_json(json_str, parser=parser)
#
# File /workspaces/New_LangGraph/myenv/lib/python3.12/site-packages/langchain_core/utils/json.py:191, in _parse_json(json_str, parser)
#     190 # Parse the JSON string into a Python dictionary
# --> 191 return parser(json_str)
#
# File /workspaces/New_LangGraph/myenv/lib/python3.12/site-packages/langchain_core/utils/json.py:136, in parse_partial_json(s, strict)
#     133 # If we got here, we ran out of characters to remove
#     134 # and still couldn't parse the string as JSON, so return the parse error
#     135 # for the original string.
# --> 136 return json.loads(s, strict=strict)
#
# File ~/.python/current/lib/python3.12/json/__init__.py:359, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     358     kw['parse_constant'] = parse_constant
# --> 359 return cls(**kw).decode(s)
#
# File ~/.python/current/lib/python3.12/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~/.python/current/lib/python3.12/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# The above exception was the direct cause of the following exception:
#
# OutputParserException                     Traceback (most recent call last)
# Cell In[20], line 6
#       2
#       3 Return ONLY one word: Positive or Negative.
#       4
#       5 Review: The Structure is too good """
# ----> 6 structured_llm.invoke(prompt).sentiment
#
# File /workspaces/New_LangGraph/myenv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3157, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3155                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3156             else:
# -> 3157                 input_ = context.run(step.invoke, input_, config)
#    3158 # finish the root run
#    3159 except BaseException as e:
#
# File /workspaces/New_LangGraph/myenv/lib/python3.12/site-packages/langchain_core/output_parsers/base.py:207, in BaseOutputParser.invoke(self, input, config, **kwargs)
#     199 @override
#     200 def invoke(
#     201     self,
#    (...)    204     **kwargs: Any,
#     205 ) -> T:
#     206     if isinstance(input, BaseMessage):
# --> 207         return self._call_with_config(
#     208             lambda inner_input: self.parse_result(
#     209                 [ChatGeneration(message=inner_input)]
#     210             ),
#     211             input,
#     212             config,
#     213             run_type="parser",
#     214         )
#     215     return self._call_with_config(
#     216         lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     217         input,
#     218         config,
#     219         run_type="parser",
#     220     )
#
# File /workspaces/New_LangGraph/myenv/lib/python3.12/site-packages/langchain_core/runnables/base.py:2060, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2056     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2057     with set_config_context(child_config) as context:
#    2058         output = cast(
#    2059             "Output",
# -> 2060             context.run(
#    2061                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2062                 func,
#    2063                 input_,
#    2064                 config,
#    2065                 run_manager,
#    2066                 **kwargs,
#    2067             ),
#    2068         )
#    2069 except BaseException as e:
#    2070     run_manager.on_chain_error(e)
#
# File /workspaces/New_LangGraph/myenv/lib/python3.12/site-packages/langchain_core/runnables/config.py:461, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     459 if run_manager is not None and accepts_run_manager(func):
#     460     kwargs["run_manager"] = run_manager
# --> 461 return func(input, **kwargs)
#
# File /workspaces/New_LangGraph/myenv/lib/python3.12/site-packages/langchain_core/output_parsers/base.py:208, in BaseOutputParser.invoke.<locals>.<lambda>(inner_input)
#     199 @override
#     200 def invoke(
#     201     self,
#    (...)    204     **kwargs: Any,
#     205 ) -> T:
#     206     if isinstance(input, BaseMessage):
#     207         return self._call_with_config(
# --> 208             lambda inner_input: self.parse_result(
#     209                 [ChatGeneration(message=inner_input)]
#     210             ),
#     211             input,
#     212             config,
#     213             run_type="parser",
#     214         )
#     215     return self._call_with_config(
#     216         lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     217         input,
#     218         config,
#     219         run_type="parser",
#     220     )
#
# File /workspaces/New_LangGraph/myenv/lib/python3.12/site-packages/langchain_core/output_parsers/pydantic.py:75, in PydanticOutputParser.parse_result(self, result, partial)
#      58 """Parse the result of an LLM call to a Pydantic object.
#      59
#      60 Args:
#    (...)     72     The parsed Pydantic object.
#      73 """
#      74 try:
# ---> 75     json_object = super().parse_result(result)
#      76     return self._parse_obj(json_object)
#      77 except OutputParserException:
#
# File /workspaces/New_LangGraph/myenv/lib/python3.12/site-packages/langchain_core/output_parsers/json.py:91, in JsonOutputParser.parse_result(self, result, partial)
#      89 except JSONDecodeError as e:
#      90     msg = f"Invalid json output: {text}"
# ---> 91     raise OutputParserException(msg, llm_output=text) from e
#
# OutputParserException: Invalid json output: Positive
# For troubleshooting, visit: https://docs.langchain.com/oss/python/langchain/errors/OUTPUT_PARSING_FAILURE
